# %% [markdown]
# # On this notebook the best models and input parameters will be searched for. The problem at hand is predicting the price of any stock symbol 28 days ahead, assuming one model for all the symbols. The best training period length, base period length, and base period step will be determined, using the MRE metrics (and/or the R^2 metrics). The step for the rolling validation will be determined taking into consideration a compromise between having enough points (I consider about 1000 different target days may be good enough), and the time needed to compute the validation.

# %%
# Basic imports
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import datetime as dt
import scipy.optimize as spo
import sys
from time import time
from sklearn.metrics import r2_score, median_absolute_error

# %matplotlib inline

# %pylab inline
pylab.rcParams['figure.figsize'] = (20.0, 10.0)

# %load_ext autoreload
# %autoreload 2

sys.path.append('../../')
import predictor.feature_extraction as fe
import utils.preprocessing as pp
import utils.misc as misc
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
AHEAD_DAYS = 28

# %% [markdown]
# ## Let's get the data.

# %%
datasets_params_list_df = pd.read_pickle('../../data/datasets_params_list_df.pkl')

# %%
print(datasets_params_list_df.shape)
datasets_params_list_df.head()
# Out:
# (25, 8)
#    base_days  ahead_days  train_val_time  step_days  GOOD_DATA_RATIO  \
# 0          7           1              -1          7             0.99
# 1          7           7              -1          7             0.99
# 2          7          14              -1          7             0.99
# 3          7          28              -1          7             0.99
# 4          7          56              -1          7             0.99
#
#    SAMPLES_GOOD_DATA_RATIO           x_filename           y_filename
# 0                      0.9   x_base7_ahead1.pkl   y_base7_ahead1.pkl
# 1                      0.9   x_base7_ahead7.pkl   y_base7_ahead7.pkl
# 2                      0.9  x_base7_ahead14.pkl  y_base7_ahead14.pkl
# 3                      0.9  x_base7_ahead28.pkl  y_base7_ahead28.pkl
# 4                      0.9  x_base7_ahead56.pkl  y_base7_ahead56.pkl

# %%
train_days_arr = 252 * np.array([1, 2, 3])
params_list_df = pd.DataFrame()

for train_days in train_days_arr:
    temp_df = datasets_params_list_df[datasets_params_list_df['ahead_days'] == AHEAD_DAYS].copy()
    temp_df['train_days'] = train_days
    params_list_df = params_list_df.append(temp_df, ignore_index=True)

# %%
print(params_list_df.shape)
params_list_df.head()
# Out:
# (15, 9)
#    base_days  ahead_days  train_val_time  step_days  GOOD_DATA_RATIO  \
# 0          7          28              -1          7             0.99
# 1         14          28              -1          7             0.99
# 2         28          28              -1          7             0.99
# 3         56          28              -1          7             0.99
# 4        112          28              -1          7             0.99
#
#    SAMPLES_GOOD_DATA_RATIO             x_filename             y_filename  \
# 0                      0.9    x_base7_ahead28.pkl    y_base7_ahead28.pkl
# 1                      0.9   x_base14_ahead28.pkl   y_base14_ahead28.pkl
# 2                      0.9   x_base28_ahead28.pkl   y_base28_ahead28.pkl
# 3                      0.9   x_base56_ahead28.pkl   y_base56_ahead28.pkl
# 4                      0.9  x_base112_ahead28.pkl  y_base112_ahead28.pkl
#
#    train_days
# 0         252
# 1         252
# 2         252
# 3         252
# 4         252

# %% [markdown]
# ## Let's find the best params set for some different models

# %% [markdown]
# ### - Dummy Predictor (mean)

# %%
tic = time()

from predictor.dummy_mean_predictor import DummyPredictor
PREDICTOR_NAME = 'dummy'

# Global variables
eval_predictor = DummyPredictor()
step_eval_days = 60  # The step to move between training/validation pairs
params = {'eval_predictor': eval_predictor, 'step_eval_days': step_eval_days}

results_df = misc.parallelize_dataframe(params_list_df, misc.apply_mean_score_eval, params)

results_df['r2'] = results_df.apply(lambda x: x['scores'][0], axis=1)
results_df['mre'] = results_df.apply(lambda x: x['scores'][1], axis=1)
# Pickle that!
results_df.to_pickle('../../data/results_ahead{}_{}_df.pkl'.format(AHEAD_DAYS, PREDICTOR_NAME))
results_df['mre'].plot()

print('Minimum MRE param set: \n {}'.format(results_df.iloc[np.argmin(results_df['mre'])]))
print('Maximum R^2 param set: \n {}'.format(results_df.iloc[np.argmax(results_df['r2'])]))

toc = time()
print('Elapsed time: {} seconds.'.format((toc-tic)))
# Out:
# Generating: base7_ahead28_train252
# Generating: base28_ahead28_train756
# Generating: base56_ahead28_train504
# Generating: base112_ahead28_train252
# Evaluating approximately 87 training/evaluation pairs
# Evaluating approximately 78 training/evaluation pairs
# Evaluating approximately 82 training/evaluation pairs
# Evaluating approximately 85 training/evaluation pairs
# Approximately 100.0 percent complete.    (0.079082964386783888, 0.0823839340747273)
# Generating: base14_ahead28_train252
# Approximately 101.2 percent complete.    Evaluating approximately 87 training/evaluation pairs
# (0.47485776636673693, 0.12780441657449021)
# Generating: base7_ahead28_train504
# Approximately 1.1 percent complete.     Evaluating approximately 83 training/evaluation pairs
# Approximately 6.9 percent complete.      (0.38176738704376689, 0.10649233694801061)
# Generating: base112_ahead28_train504
# Approximately 8.0 percent complete.     Evaluating approximately 81 training/evaluation pairs
# Approximately 12.0 percent complete.     (0.30004383442511551, 0.094532016195179855)
# Generating: base56_ahead28_train756
# Approximately 13.3 percent complete.    Evaluating approximately 78 training/evaluation pairs
# Approximately 95.2 percent complete.     (0.18112320268453319, 0.084163629382307467)
# Generating: base28_ahead28_train252
# Approximately 78.2 percent complete.    Evaluating approximately 86 training/evaluation pairs
# Approximately 82.1 percent complete.     (0.075964145547270739, 0.087791760005942368)
# Generating: base14_ahead28_train504
# Approximately 95.1 percent complete.    Evaluating approximately 82 training/evaluation pairs
# Approximately 12.8 percent complete.     (0.4767551341781871, 0.12942677014161696)
# Generating: base7_ahead28_train756
# Approximately 7.3 percent complete.    Evaluating approximately 78 training/evaluation pairs
# Approximately 24.4 percent complete.     (0.42263626032537366, 0.10829690668027665)
# Generating: base112_ahead28_train756
# Approximately 10.3 percent complete.    Evaluating approximately 77 training/evaluation pairs
# Approximately 92.7 percent complete.     (0.2608046791665114, 0.09253186295305349)
# Generating: base56_ahead28_train252
# Approximately 68.8 percent complete.    Evaluating approximately 86 training/evaluation pairs
# Approximately 9.3 percent complete.      (0.15557450819844074, 0.087114213648123759)
# Generating: base28_ahead28_train504
# Approximately 92.3 percent complete.    Evaluating approximately 82 training/evaluation pairs
# Approximately 22.1 percent complete.     (0.075895097817834573, 0.086184395734880098)
# Generating: base14_ahead28_train756
# Approximately 88.3 percent complete.    Evaluating approximately 78 training/evaluation pairs
# Approximately 23.2 percent complete.     (0.49547139987927086, 0.13528911614633216)
# Approximately 71.8 percent complete.     (0.37858785468918443, 0.1075743738763854)
# Approximately 101.2 percent complete.    (0.26062894955907129, 0.093933452510438706)
# Approximately 101.3 percent complete.    (0.18407617883239344, 0.087930702314113429)
# Minimum MRE param set:
#  base_days                                                   7
# ahead_days                                                 28
# train_val_time                                             -1
# step_days                                                   7
# GOOD_DATA_RATIO                                          0.99
# SAMPLES_GOOD_DATA_RATIO                                   0.9
# x_filename                                x_base7_ahead28.pkl
# y_filename                                y_base7_ahead28.pkl
# train_days                                                252
# scores                     (0.0790829643868, 0.0823839340747)
# r2                                                   0.079083
# mre                                                 0.0823839
# Name: 0, dtype: object
# Maximum R^2 param set:
#  base_days                                               112
# ahead_days                                               28
# train_val_time                                           -1
# step_days                                                 7
# GOOD_DATA_RATIO                                        0.99
# SAMPLES_GOOD_DATA_RATIO                                 0.9
# x_filename                            x_base112_ahead28.pkl
# y_filename                            y_base112_ahead28.pkl
# train_days                                              756
# scores                     (0.495471399879, 0.135289116146)
# r2                                                 0.495471
# mre                                                0.135289
# Name: 14, dtype: object
# Elapsed time: 450.3584406375885 seconds.

# %% [markdown]
# ### - Linear Predictor

# %%
tic = time()

from predictor.linear_predictor import LinearPredictor
PREDICTOR_NAME = 'linear'

# Global variables
eval_predictor = LinearPredictor()
step_eval_days = 60  # The step to move between training/validation pairs
params = {'eval_predictor': eval_predictor, 'step_eval_days': step_eval_days}

results_df = misc.parallelize_dataframe(params_list_df, misc.apply_mean_score_eval, params)

results_df['r2'] = results_df.apply(lambda x: x['scores'][0], axis=1)
results_df['mre'] = results_df.apply(lambda x: x['scores'][1], axis=1)
# Pickle that!
results_df.to_pickle('../../data/results_ahead{}_{}_df.pkl'.format(AHEAD_DAYS, PREDICTOR_NAME))
results_df['mre'].plot()

print('Minimum MRE param set: \n {}'.format(results_df.iloc[np.argmin(results_df['mre'])]))
print('Maximum R^2 param set: \n {}'.format(results_df.iloc[np.argmax(results_df['r2'])]))

toc = time()
print('Elapsed time: {} seconds.'.format((toc-tic)))
# Out:
# Generating: base112_ahead28_train252
# Generating: base7_ahead28_train252
# Generating: base56_ahead28_train504
# Generating: base28_ahead28_train756
# Evaluating approximately 87 training/evaluation pairs
# Evaluating approximately 78 training/evaluation pairs
# Evaluating approximately 82 training/evaluation pairs
# Evaluating approximately 85 training/evaluation pairs
# Approximately 96.5 percent complete.     (0.028868865069598196, 0.08383873339681977)
# Generating: base14_ahead28_train252
# Approximately 89.7 percent complete.    Evaluating approximately 87 training/evaluation pairs
# Approximately 4.6 percent complete.      (0.68360932186322299, 0.092388316088325068)
# Generating: base7_ahead28_train504
# Evaluating approximately 83 training/evaluation pairs
# Approximately 6.0 percent complete.      (0.58814414157043426, 0.085465029890768082)
# Generating: base112_ahead28_train504
# Approximately 12.6 percent complete.    Evaluating approximately 81 training/evaluation pairs
# Approximately 13.8 percent complete.     (0.42586038824342737, 0.084480398966402429)
# Generating: base56_ahead28_train756
# Approximately 8.4 percent complete.     Evaluating approximately 78 training/evaluation pairs
# Approximately 75.3 percent complete.     (0.13401817981042688, 0.085272888178159159)
# Generating: base28_ahead28_train252
# Approximately 90.4 percent complete.    Evaluating approximately 86 training/evaluation pairs
# Approximately 10.5 percent complete.     (0.11403804778791635, 0.086077974316491723)
# Generating: base14_ahead28_train504
# Evaluating approximately 82 training/evaluation pairs
# Approximately 29.1 percent complete.     (0.7435547235787463, 0.087843282449596827)
# Generating: base7_ahead28_train756
# Approximately 17.1 percent complete.    Evaluating approximately 78 training/evaluation pairs
# Approximately 1.3 percent complete.      (0.62449092407513518, 0.087009387135841817)
# Generating: base112_ahead28_train756
# Approximately 32.6 percent complete.    Evaluating approximately 77 training/evaluation pairs
# Approximately 51.9 percent complete.     (0.31682732798762459, 0.086850158721410817)
# Generating: base56_ahead28_train252
# Approximately 85.4 percent complete.    Evaluating approximately 86 training/evaluation pairs
# Approximately 66.2 percent complete.     (0.20890384442166818, 0.08317845500701429)
# Generating: base28_ahead28_train504
# Approximately 80.8 percent complete.    Evaluating approximately 82 training/evaluation pairs
# Approximately 40.7 percent complete.     (0.11036198467472115, 0.085115034981567833)
# Generating: base14_ahead28_train756
# Approximately 23.2 percent complete.    Evaluating approximately 78 training/evaluation pairs
# Approximately 41.5 percent complete.     (0.75804589355498531, 0.091966446970869697)
# Approximately 53.8 percent complete.     (0.53957269927850871, 0.089751531663860698)
# Approximately 74.4 percent complete.     (0.36764780622275001, 0.086340273747722962)
# Approximately 101.3 percent complete.    (0.24578922618415, 0.085277495885574331)
# Minimum MRE param set:
#  base_days                                                14
# ahead_days                                               28
# train_val_time                                           -1
# step_days                                                 7
# GOOD_DATA_RATIO                                        0.99
# SAMPLES_GOOD_DATA_RATIO                                 0.9
# x_filename                             x_base14_ahead28.pkl
# y_filename                             y_base14_ahead28.pkl
# train_days                                              504
# scores                     (0.208903844422, 0.083178455007)
# r2                                                 0.208904
# mre                                               0.0831785
# Name: 6, dtype: object
# Maximum R^2 param set:
#  base_days                                                112
# ahead_days                                                28
# train_val_time                                            -1
# step_days                                                  7
# GOOD_DATA_RATIO                                         0.99
# SAMPLES_GOOD_DATA_RATIO                                  0.9
# x_filename                             x_base112_ahead28.pkl
# y_filename                             y_base112_ahead28.pkl
# train_days                                               756
# scores                     (0.758045893555, 0.0919664469709)
# r2                                                  0.758046
# mre                                                0.0919664
# Name: 14, dtype: object
# Elapsed time: 456.75867676734924 seconds.

# %% [markdown]
# ### - Random Forest model

# %%
tic = time()

from predictor.random_forest_predictor import RandomForestPredictor
PREDICTOR_NAME = 'random_forest'

# Global variables
eval_predictor = RandomForestPredictor()
step_eval_days = 60  # The step to move between training/validation pairs
params = {'eval_predictor': eval_predictor, 'step_eval_days': step_eval_days}

results_df = misc.parallelize_dataframe(params_list_df, misc.apply_mean_score_eval, params)

results_df['r2'] = results_df.apply(lambda x: x['scores'][0], axis=1)
results_df['mre'] = results_df.apply(lambda x: x['scores'][1], axis=1)
# Pickle that!
results_df.to_pickle('../../data/results_ahead{}_{}_df.pkl'.format(AHEAD_DAYS, PREDICTOR_NAME))
results_df['mre'].plot()

print('Minimum MRE param set: \n {}'.format(results_df.iloc[np.argmin(results_df['mre'])]))
print('Maximum R^2 param set: \n {}'.format(results_df.iloc[np.argmax(results_df['r2'])]))

toc = time()
print('Elapsed time: {} seconds.'.format((toc-tic)))
# Out:
# Generating: base56_ahead28_train504
# Generating: base7_ahead28_train252
# Generating: base112_ahead28_train252
# Generating: base28_ahead28_train756
# Evaluating approximately 87 training/evaluation pairs
# Evaluating approximately 78 training/evaluation pairs
# Evaluating approximately 82 training/evaluation pairs
# Evaluating approximately 85 training/evaluation pairs
# Approximately 101.1 percent complete.    (-0.41911302360830877, 0.092590043933107935)
# Generating: base14_ahead28_train252
# Evaluating approximately 87 training/evaluation pairs
# Approximately 101.1 percent complete.    (-0.25676637643844735, 0.091856067802060057)
# Generating: base28_ahead28_train252
# Evaluating approximately 86 training/evaluation pairs
# Approximately 64.7 percent complete.     (-0.16099446955371799, 0.093617833164231223)
# Generating: base56_ahead28_train252
# Evaluating approximately 86 training/evaluation pairs
# Approximately 101.2 percent complete.    (0.62023178123219669, 0.093106537439816478)
# Generating: base7_ahead28_train504
# Evaluating approximately 83 training/evaluation pairs
# Approximately 101.3 percent complete.    (0.22868165575574487, 0.091754107138754745)
# Generating: base56_ahead28_train756
# Approximately 83.1 percent complete.    Evaluating approximately 78 training/evaluation pairs
# Approximately 91.5 percent complete.     (0.39818537821100758, 0.0954933817207025)
# Approximately 100.0 percent complete.    (-0.27431204474528381, 0.09513615079909396)
# Generating: base14_ahead28_train504
# Evaluating approximately 82 training/evaluation pairs
# Approximately 101.2 percent complete.    (0.4770479208452495, 0.089484880518962862)
# Generating: base112_ahead28_train504
# Evaluating approximately 81 training/evaluation pairs
# Approximately 101.2 percent complete.    (-0.053237242165382191, 0.090515992385870034)
# Generating: base28_ahead28_train504
# Evaluating approximately 82 training/evaluation pairs
# Approximately 101.2 percent complete.    (0.16553464544156479, 0.094044071452278513)
# Approximately 100.0 percent complete.    (0.54204121376205061, 0.093511998024614837)
# Generating: base112_ahead28_train756
# Evaluating approximately 77 training/evaluation pairs
# Approximately 101.2 percent complete.    (0.70849633825318958, 0.089580576629362224)
# Generating: base7_ahead28_train756
# Evaluating approximately 78 training/evaluation pairs
# Approximately 101.3 percent complete.    (-0.57364992663288805, 0.093926396712410667)
# Generating: base14_ahead28_train756
# Evaluating approximately 78 training/evaluation pairs
# Approximately 32.5 percent complete.     (0.040280433067372765, 0.092796128719444967)
# Approximately 100.0 percent complete.    (0.71580166418108204, 0.096087196275614684)
# Minimum MRE param set:
#  base_days                                                56
# ahead_days                                               28
# train_val_time                                           -1
# step_days                                                 7
# GOOD_DATA_RATIO                                        0.99
# SAMPLES_GOOD_DATA_RATIO                                 0.9
# x_filename                             x_base56_ahead28.pkl
# y_filename                             y_base56_ahead28.pkl
# train_days                                              504
# scores                     (0.477047920845, 0.089484880519)
# r2                                                 0.477048
# mre                                               0.0894849
# Name: 8, dtype: object
# Maximum R^2 param set:
#  base_days                                                112
# ahead_days                                                28
# train_val_time                                            -1
# step_days                                                  7
# GOOD_DATA_RATIO                                         0.99
# SAMPLES_GOOD_DATA_RATIO                                  0.9
# x_filename                             x_base112_ahead28.pkl
# y_filename                             y_base112_ahead28.pkl
# train_days                                               756
# scores                     (0.715801664181, 0.0960871962756)
# r2                                                  0.715802
# mre                                                0.0960872
# Name: 14, dtype: object
# Elapsed time: 7884.518784999847 seconds.
