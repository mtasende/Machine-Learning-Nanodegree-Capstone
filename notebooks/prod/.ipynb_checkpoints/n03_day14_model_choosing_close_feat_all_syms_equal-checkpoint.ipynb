# %% [markdown]
# # On this notebook the best models and input parameters will be searched for. The problem at hand is predicting the price of any stock symbol 14 days ahead, assuming one model for all the symbols. The best training period length, base period length, and base period step will be determined, using the MRE metrics (and/or the R^2 metrics). The step for the rolling validation will be determined taking into consideration a compromise between having enough points (I consider about 1000 different target days may be good enough), and the time needed to compute the validation.

# %%
# Basic imports
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import datetime as dt
import scipy.optimize as spo
import sys
from time import time
from sklearn.metrics import r2_score, median_absolute_error

# %matplotlib inline

# %pylab inline
pylab.rcParams['figure.figsize'] = (20.0, 10.0)

# %load_ext autoreload
# %autoreload 2

sys.path.append('../../')
import predictor.feature_extraction as fe
import utils.preprocessing as pp
import utils.misc as misc
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
AHEAD_DAYS = 14

# %% [markdown]
# ## Let's get the data.

# %%
datasets_params_list_df = pd.read_pickle('../../data/datasets_params_list_df.pkl')

# %%
print(datasets_params_list_df.shape)
datasets_params_list_df.head()
# Out:
# (25, 8)
#    base_days  ahead_days  train_val_time  step_days  GOOD_DATA_RATIO  \
# 0          7           1              -1          7             0.99
# 1          7           7              -1          7             0.99
# 2          7          14              -1          7             0.99
# 3          7          28              -1          7             0.99
# 4          7          56              -1          7             0.99
#
#    SAMPLES_GOOD_DATA_RATIO           x_filename           y_filename
# 0                      0.9   x_base7_ahead1.pkl   y_base7_ahead1.pkl
# 1                      0.9   x_base7_ahead7.pkl   y_base7_ahead7.pkl
# 2                      0.9  x_base7_ahead14.pkl  y_base7_ahead14.pkl
# 3                      0.9  x_base7_ahead28.pkl  y_base7_ahead28.pkl
# 4                      0.9  x_base7_ahead56.pkl  y_base7_ahead56.pkl

# %%
train_days_arr = 252 * np.array([1, 2, 3])
params_list_df = pd.DataFrame()

for train_days in train_days_arr:
    temp_df = datasets_params_list_df[datasets_params_list_df['ahead_days'] == AHEAD_DAYS].copy()
    temp_df['train_days'] = train_days
    params_list_df = params_list_df.append(temp_df, ignore_index=True)

# %%
print(params_list_df.shape)
params_list_df.head()
# Out:
# (15, 9)
#    base_days  ahead_days  train_val_time  step_days  GOOD_DATA_RATIO  \
# 0          7          14              -1          7             0.99
# 1         14          14              -1          7             0.99
# 2         28          14              -1          7             0.99
# 3         56          14              -1          7             0.99
# 4        112          14              -1          7             0.99
#
#    SAMPLES_GOOD_DATA_RATIO             x_filename             y_filename  \
# 0                      0.9    x_base7_ahead14.pkl    y_base7_ahead14.pkl
# 1                      0.9   x_base14_ahead14.pkl   y_base14_ahead14.pkl
# 2                      0.9   x_base28_ahead14.pkl   y_base28_ahead14.pkl
# 3                      0.9   x_base56_ahead14.pkl   y_base56_ahead14.pkl
# 4                      0.9  x_base112_ahead14.pkl  y_base112_ahead14.pkl
#
#    train_days
# 0         252
# 1         252
# 2         252
# 3         252
# 4         252

# %% [markdown]
# ## Let's find the best params set for some different models

# %% [markdown]
# ### - Dummy Predictor (mean)

# %%
from predictor.dummy_mean_predictor import DummyPredictor
PREDICTOR_NAME = 'dummy'

# Global variables
eval_predictor = DummyPredictor()
step_eval_days = 60  # The step to move between training/validation pairs
params = {'eval_predictor': eval_predictor, 'step_eval_days': step_eval_days}

results_df = misc.parallelize_dataframe(params_list_df, misc.apply_mean_score_eval, params)

results_df['r2'] = results_df.apply(lambda x: x['scores'][0], axis=1)
results_df['mre'] = results_df.apply(lambda x: x['scores'][1], axis=1)
# Pickle that!
results_df.to_pickle('../../data/results_ahead{}_{}_df.pkl'.format(AHEAD_DAYS, PREDICTOR_NAME))
results_df['mre'].plot()

print('Minimum MRE param set: \n {}'.format(results_df.iloc[np.argmin(results_df['mre'])]))
print('Maximum R^2 param set: \n {}'.format(results_df.iloc[np.argmax(results_df['r2'])]))
# Out:
# Generating: base56_ahead14_train504
# Generating: base112_ahead14_train252
# Generating: base28_ahead14_train756
# Generating: base7_ahead14_train252
# Evaluating approximately 87 training/evaluation pairs
# Evaluating approximately 78 training/evaluation pairs
# Evaluating approximately 82 training/evaluation pairs
# Evaluating approximately 85 training/evaluation pairs
# Approximately 89.7 percent complete.     (0.5458709844748032, 0.10940459297828167)
# Generating: base7_ahead14_train504
# Approximately 101.1 percent complete.    Evaluating approximately 83 training/evaluation pairs
# Approximately 91.0 percent complete.    (0.13611116617650759, 0.058850774133939202)
# Generating: base14_ahead14_train252
# Approximately 97.6 percent complete.    Evaluating approximately 87 training/evaluation pairs
# Approximately 101.2 percent complete.    (0.4726393408267055, 0.090151702748153859)
# Generating: base112_ahead14_train504
# Approximately 6.0 percent complete.     Evaluating approximately 81 training/evaluation pairs
# Approximately 11.5 percent complete.     (0.42123899323807856, 0.073570855755131448)
# Generating: base56_ahead14_train756
# Approximately 13.3 percent complete.    Evaluating approximately 78 training/evaluation pairs
# Approximately 98.8 percent complete.     (0.3197073090848736, 0.062910913469966911)
# Generating: base28_ahead14_train252
# Approximately 80.8 percent complete.    Evaluating approximately 87 training/evaluation pairs
# Approximately 2.3 percent complete.      (0.19621151188164151, 0.061341976822861251)
# Generating: base14_ahead14_train504
# Approximately 83.3 percent complete.    Evaluating approximately 83 training/evaluation pairs
# Approximately 6.0 percent complete.      (0.54802300154672057, 0.11407938829774285)
# Generating: base7_ahead14_train756
# Approximately 89.7 percent complete.    Evaluating approximately 79 training/evaluation pairs
# Approximately 12.7 percent complete.     (0.50725383514890199, 0.089474186819732265)
# Generating: base112_ahead14_train756
# Approximately 25.3 percent complete.    Evaluating approximately 77 training/evaluation pairs
# Approximately 82.3 percent complete.     (0.40375181379938574, 0.071259144368452959)
# Generating: base56_ahead14_train252
# Approximately 83.5 percent complete.    Evaluating approximately 86 training/evaluation pairs
# Approximately 9.3 percent complete.      (0.29989326767222135, 0.064220179427016535)
# Generating: base28_ahead14_train504
# Approximately 92.4 percent complete.    Evaluating approximately 82 training/evaluation pairs
# Approximately 19.8 percent complete.     (0.18045054937842647, 0.06428139515926734)
# Generating: base14_ahead14_train756
# Approximately 9.8 percent complete.     Evaluating approximately 79 training/evaluation pairs
# Approximately 37.2 percent complete.     (0.56787685750491668, 0.11371186561645694)
# Approximately 89.0 percent complete.     (0.4744111449093309, 0.086410888746687731)
# Approximately 87.3 percent complete.     (0.38262968660653557, 0.073603137738176533)
# Approximately 100.0 percent complete.    (0.30223946647094574, 0.066424264344321721)
# Minimum MRE param set:
#  base_days                                                  7
# ahead_days                                                14
# train_val_time                                            -1
# step_days                                                  7
# GOOD_DATA_RATIO                                         0.99
# SAMPLES_GOOD_DATA_RATIO                                  0.9
# x_filename                               x_base7_ahead14.pkl
# y_filename                               y_base7_ahead14.pkl
# train_days                                               252
# scores                     (0.136111166177, 0.0588507741339)
# r2                                                  0.136111
# mre                                                0.0588508
# Name: 0, dtype: object
# Maximum R^2 param set:
#  base_days                                               112
# ahead_days                                               14
# train_val_time                                           -1
# step_days                                                 7
# GOOD_DATA_RATIO                                        0.99
# SAMPLES_GOOD_DATA_RATIO                                 0.9
# x_filename                            x_base112_ahead14.pkl
# y_filename                            y_base112_ahead14.pkl
# train_days                                              756
# scores                     (0.567876857505, 0.113711865616)
# r2                                                 0.567877
# mre                                                0.113712
# Name: 14, dtype: object

# %% [markdown]
# ### - Linear Predictor

# %%
from predictor.linear_predictor import LinearPredictor
PREDICTOR_NAME = 'linear'

# Global variables
eval_predictor = LinearPredictor()
step_eval_days = 60  # The step to move between training/validation pairs
params = {'eval_predictor': eval_predictor, 'step_eval_days': step_eval_days}

results_df = misc.parallelize_dataframe(params_list_df, misc.apply_mean_score_eval, params)

results_df['r2'] = results_df.apply(lambda x: x['scores'][0], axis=1)
results_df['mre'] = results_df.apply(lambda x: x['scores'][1], axis=1)
# Pickle that!
results_df.to_pickle('../../data/results_ahead{}_{}_df.pkl'.format(AHEAD_DAYS, PREDICTOR_NAME))
results_df['mre'].plot()

print('Minimum MRE param set: \n {}'.format(results_df.iloc[np.argmin(results_df['mre'])]))
print('Maximum R^2 param set: \n {}'.format(results_df.iloc[np.argmax(results_df['r2'])]))
# Out:
# Generating: base112_ahead14_train252
# Generating: base7_ahead14_train252
# Generating: base56_ahead14_train504
# Generating: base28_ahead14_train756
# Evaluating approximately 87 training/evaluation pairs
# Evaluating approximately 78 training/evaluation pairs
# Evaluating approximately 82 training/evaluation pairs
# Evaluating approximately 85 training/evaluation pairs
# Approximately 92.7 percent complete.     (0.12364687562449182, 0.056044234007377784)
# Generating: base14_ahead14_train252
# Approximately 91.0 percent complete.     Evaluating approximately 87 training/evaluation pairs
# Approximately 95.1 percent complete.     (0.81656514554471138, 0.064609005209086398)
# Generating: base7_ahead14_train504
# Evaluating approximately 83 training/evaluation pairs
# Approximately 9.2 percent complete.      (0.7691831137000954, 0.057604116577658654)
# Generating: base112_ahead14_train504
# Approximately 10.3 percent complete.     Evaluating approximately 81 training/evaluation pairs
# Approximately 1.2 percent complete.      (0.60583160216459453, 0.058848755903359619)
# Generating: base56_ahead14_train756
# Approximately 12.6 percent complete.    Evaluating approximately 78 training/evaluation pairs
# Approximately 95.2 percent complete.     (0.3811420545404528, 0.059019281696440176)
# Generating: base28_ahead14_train252
# Approximately 75.6 percent complete.    Evaluating approximately 87 training/evaluation pairs
# Approximately 84.0 percent complete.     (0.3020240856228868, 0.057047036429245523)
# Generating: base14_ahead14_train504
# Approximately 6.9 percent complete.     Evaluating approximately 83 training/evaluation pairs
# Approximately 18.1 percent complete.     (0.85120870287373374, 0.060074597234695173)
# Generating: base7_ahead14_train756
# Approximately 19.3 percent complete.    Evaluating approximately 79 training/evaluation pairs
# Approximately 22.9 percent complete.     (0.77064784484902626, 0.058464885062895815)
# Generating: base112_ahead14_train756
# Approximately 24.1 percent complete.    Evaluating approximately 77 training/evaluation pairs
# Approximately 90.4 percent complete.     (0.5611382967414773, 0.058814054711583477)
# Generating: base56_ahead14_train252
# Evaluating approximately 86 training/evaluation pairs
# Approximately 77.2 percent complete.     (0.39370354597043944, 0.058052264207363591)
# Generating: base28_ahead14_train504
# Evaluating approximately 82 training/evaluation pairs
# Approximately 81.8 percent complete.     (0.22660258505486089, 0.061522325083183456)
# Generating: base14_ahead14_train756
# Evaluating approximately 79 training/evaluation pairs
# Approximately 65.1 percent complete.     (0.86525913723154835, 0.060166842329153598)
# Approximately 82.9 percent complete.     (0.7134834470285667, 0.062049855602305998)
# Approximately 101.2 percent complete.    (0.56389250346290865, 0.059868179573918635)
# Approximately 100.0 percent complete.    (0.434019296889322, 0.059536056917843069)
# Minimum MRE param set:
#  base_days                                                  7
# ahead_days                                                14
# train_val_time                                            -1
# step_days                                                  7
# GOOD_DATA_RATIO                                         0.99
# SAMPLES_GOOD_DATA_RATIO                                  0.9
# x_filename                               x_base7_ahead14.pkl
# y_filename                               y_base7_ahead14.pkl
# train_days                                               252
# scores                     (0.123646875624, 0.0560442340074)
# r2                                                  0.123647
# mre                                                0.0560442
# Name: 0, dtype: object
# Maximum R^2 param set:
#  base_days                                                112
# ahead_days                                                14
# train_val_time                                            -1
# step_days                                                  7
# GOOD_DATA_RATIO                                         0.99
# SAMPLES_GOOD_DATA_RATIO                                  0.9
# x_filename                             x_base112_ahead14.pkl
# y_filename                             y_base112_ahead14.pkl
# train_days                                               756
# scores                     (0.865259137232, 0.0601668423292)
# r2                                                  0.865259
# mre                                                0.0601668
# Name: 14, dtype: object

# %% [markdown]
# ### - Random Forest model

# %%
from predictor.random_forest_predictor import RandomForestPredictor
PREDICTOR_NAME = 'random_forest'

# Global variables
eval_predictor = RandomForestPredictor()
step_eval_days = 60  # The step to move between training/validation pairs
params = {'eval_predictor': eval_predictor, 'step_eval_days': step_eval_days}

results_df = misc.parallelize_dataframe(params_list_df, misc.apply_mean_score_eval, params)

results_df['r2'] = results_df.apply(lambda x: x['scores'][0], axis=1)
results_df['mre'] = results_df.apply(lambda x: x['scores'][1], axis=1)
# Pickle that!
results_df.to_pickle('../../data/results_ahead{}_{}_df.pkl'.format(AHEAD_DAYS, PREDICTOR_NAME))
results_df['mre'].plot()

print('Minimum MRE param set: \n {}'.format(results_df.iloc[np.argmin(results_df['mre'])]))
print('Maximum R^2 param set: \n {}'.format(results_df.iloc[np.argmax(results_df['r2'])]))
# Out:
# Generating: base56_ahead14_train504
# Generating: base112_ahead14_train252
# Generating: base7_ahead14_train252
# Generating: base28_ahead14_train756
# Evaluating approximately 87 training/evaluation pairs
# Evaluating approximately 82 training/evaluation pairs
# Evaluating approximately 78 training/evaluation pairs
# Evaluating approximately 85 training/evaluation pairs
# Approximately 101.1 percent complete.    (-0.33504050633388921, 0.062858118990877787)
# Generating: base14_ahead14_train252
# Approximately 11.8 percent complete.    Evaluating approximately 87 training/evaluation pairs
# Approximately 101.1 percent complete.    (-0.11594637935502691, 0.06403972658806624)
# Generating: base28_ahead14_train252
# Approximately 32.9 percent complete.    Evaluating approximately 87 training/evaluation pairs
# Approximately 101.1 percent complete.    (0.2269685727115317, 0.064682501729347183)
# Generating: base56_ahead14_train252
# Approximately 59.0 percent complete.    Evaluating approximately 86 training/evaluation pairs
# Approximately 87.2 percent complete.     (0.77683196359250095, 0.064629072286523412)
# Generating: base7_ahead14_train504
# Evaluating approximately 83 training/evaluation pairs
# Approximately 101.3 percent complete.    (0.33277457858279524, 0.063723559967323998)
# Generating: base56_ahead14_train756
# Approximately 63.9 percent complete.    Evaluating approximately 78 training/evaluation pairs
# Approximately 101.2 percent complete.    (0.049099955118841722, 0.062969172894913425)
# Generating: base14_ahead14_train504
# Evaluating approximately 83 training/evaluation pairs
# Approximately 101.2 percent complete.    (0.64818776392956323, 0.06435634127148529)
# Approximately 101.2 percent complete.    (0.71952872483184904, 0.061386622787507845)
# Generating: base112_ahead14_train504
# Evaluating approximately 81 training/evaluation pairs
# Approximately 101.2 percent complete.    (0.085326992194521376, 0.063210320165528938)
# Generating: base28_ahead14_train504
# Evaluating approximately 82 training/evaluation pairs
# Approximately 101.2 percent complete.    (0.40048357434068388, 0.064825202393482231)
# Approximately 101.3 percent complete.    (0.71747705617642954, 0.062892101719533161)
# Generating: base112_ahead14_train756
# Evaluating approximately 77 training/evaluation pairs
# Approximately 101.2 percent complete.    (0.82678302925518554, 0.062519699870578899)
# Generating: base7_ahead14_train756
# Evaluating approximately 79 training/evaluation pairs
# Approximately 100.0 percent complete.    (-0.018259396473777022, 0.06825240318625353)
# Generating: base14_ahead14_train756
# Evaluating approximately 79 training/evaluation pairs
# Approximately 100.0 percent complete.    (0.30997030913832763, 0.064667225662814867)
# Approximately 101.3 percent complete.    (0.82945201790456402, 0.06332672790974371)
# Minimum MRE param set:
#  base_days                                                 56
# ahead_days                                                14
# train_val_time                                            -1
# step_days                                                  7
# GOOD_DATA_RATIO                                         0.99
# SAMPLES_GOOD_DATA_RATIO                                  0.9
# x_filename                              x_base56_ahead14.pkl
# y_filename                              y_base56_ahead14.pkl
# train_days                                               504
# scores                     (0.719528724832, 0.0613866227875)
# r2                                                  0.719529
# mre                                                0.0613866
# Name: 8, dtype: object
# Maximum R^2 param set:
#  base_days                                                112
# ahead_days                                                14
# train_val_time                                            -1
# step_days                                                  7
# GOOD_DATA_RATIO                                         0.99
# SAMPLES_GOOD_DATA_RATIO                                  0.9
# x_filename                             x_base112_ahead14.pkl
# y_filename                             y_base112_ahead14.pkl
# train_days                                               756
# scores                     (0.829452017905, 0.0633267279097)
# r2                                                  0.829452
# mre                                                0.0633267
# Name: 14, dtype: object
