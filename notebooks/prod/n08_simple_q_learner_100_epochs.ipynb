# %% [markdown]
# # In this notebook a simple Q learner will be trained and evaluated. The Q learner recommends when to buy or sell shares of one particular stock, and in which quantity (in fact it determines the desired fraction of shares in the total portfolio value). One initial attempt was made to train the Q-learner with multiple processes, but it was unsuccessful.

# %%
# Basic imports
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import datetime as dt
import scipy.optimize as spo
import sys
from time import time
from sklearn.metrics import r2_score, median_absolute_error
from multiprocessing import Pool

# %matplotlib inline

# %pylab inline
pylab.rcParams['figure.figsize'] = (20.0, 10.0)

# %load_ext autoreload
# %autoreload 2

sys.path.append('../../')

import recommender.simulator as sim
from utils.analysis import value_eval
from recommender.agent import Agent
from functools import partial
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
NUM_THREADS = 1
LOOKBACK = 252*2 + 28
STARTING_DAYS_AHEAD = 20
POSSIBLE_FRACTIONS = [0.0, 1.0]

# Get the data
SYMBOL = 'SPY'
total_data_train_df = pd.read_pickle('../../data/data_train_val_df.pkl').stack(level='feature')
data_train_df = total_data_train_df[SYMBOL].unstack()
total_data_test_df = pd.read_pickle('../../data/data_test_df.pkl').stack(level='feature')
data_test_df = total_data_test_df[SYMBOL].unstack()
if LOOKBACK == -1:
    total_data_in_df = total_data_train_df
    data_in_df = data_train_df
else:
    data_in_df = data_train_df.iloc[-LOOKBACK:]
    total_data_in_df = total_data_train_df.loc[data_in_df.index[0]:]

# Create many agents
index = np.arange(NUM_THREADS).tolist()
env, num_states, num_actions = sim.initialize_env(total_data_in_df, 
                                                  SYMBOL, 
                                                  starting_days_ahead=STARTING_DAYS_AHEAD,
                                                  possible_fractions=POSSIBLE_FRACTIONS)
agents = [Agent(num_states=num_states, 
                num_actions=num_actions, 
                random_actions_rate=0.98, 
                random_actions_decrease=0.9999,
                dyna_iterations=0,
                name='Agent_{}'.format(i)) for i in index]

# %%
def show_results(results_list, data_in_df, graph=False):
    for values in results_list:
        total_value = values.sum(axis=1)
        print('Sharpe ratio: {}\nCum. Ret.: {}\nAVG_DRET: {}\nSTD_DRET: {}\nFinal value: {}'.format(*value_eval(pd.DataFrame(total_value))))
        print('-'*100)
        initial_date = total_value.index[0]
        compare_results = data_in_df.loc[initial_date:, 'Close'].copy()
        compare_results.name = SYMBOL
        compare_results_df = pd.DataFrame(compare_results)
        compare_results_df['portfolio'] = total_value
        std_comp_df = compare_results_df / compare_results_df.iloc[0]
        if graph:
            plt.figure()
            std_comp_df.plot()

# %% [markdown]
# ## Let's show the symbols data, to see how good the recommender has to be.

# %%
print('Sharpe ratio: {}\nCum. Ret.: {}\nAVG_DRET: {}\nSTD_DRET: {}\nFinal value: {}'.format(*value_eval(pd.DataFrame(data_in_df['Close'].iloc[STARTING_DAYS_AHEAD:]))))
# Out:
# Sharpe ratio: 1.601691549431671
# Cum. Ret.: 0.4244923418116293
# AVG_DRET: 0.0007179294312480581
# STD_DRET: 0.00711546265440581
# Final value: 205.54

# %%
# Simulate (with new envs, each time)
n_epochs = 100

for i in range(n_epochs):
    tic = time()
    env.reset(STARTING_DAYS_AHEAD)
    results_list = sim.simulate_period(total_data_in_df, 
                                       SYMBOL,
                                       agents[0],
                                       starting_days_ahead=STARTING_DAYS_AHEAD,
                                       possible_fractions=POSSIBLE_FRACTIONS,
                                       verbose=False,
                                       other_env=env)
    toc = time()
    print('Epoch: {}'.format(i))
    print('Elapsed time: {} seconds.'.format((toc-tic)))
    print('Random Actions Rate: {}'.format(agents[0].random_actions_rate))
    show_results([results_list], data_in_df)
# Out:
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.3845806121826172s.  Value: 12015.379999999997.Epoch: 0
# Elapsed time: 16.70756435394287 seconds.
# Random Actions Rate: 0.931177595147864
# Sharpe ratio: 1.0845216083868148
# Cum. Ret.: 0.20153799999999977
# AVG_DRET: 0.0003751314898243077
# STD_DRET: 0.005490925897736176
# Final value: 12015.379999999997
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.35728907585144043s.  Value: 11700.099999999988.Epoch: 1
# Elapsed time: 19.76893186569214 seconds.
# Random Actions Rate: 0.8847874629646538
# Sharpe ratio: 1.0294204241675382
# Cum. Ret.: 0.17000999999999866
# AVG_DRET: 0.0003200741526620345
# STD_DRET: 0.004935806143898557
# Final value: 11700.099999999988
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.35195446014404297s.  Value: 12971.649999999996.Epoch: 2
# Elapsed time: 18.56040906906128 seconds.
# Random Actions Rate: 0.8407084305922503
# Sharpe ratio: 1.7576308019649487
# Cum. Ret.: 0.2971649999999997
# AVG_DRET: 0.0005213636732656639
# STD_DRET: 0.004708834030020337
# Final value: 12971.649999999996
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.42353367805480957s.  Value: 14182.13999999999.Epoch: 3
# Elapsed time: 18.917976140975952 seconds.
# Random Actions Rate: 0.7988253618565566
# Sharpe ratio: 2.163079798788326
# Cum. Ret.: 0.418213999999999
# AVG_DRET: 0.0006984357307992003
# STD_DRET: 0.005125711732386725
# Final value: 14182.13999999999
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.37378811836242676s.  Value: 12569.169999999984.Epoch: 4
# Elapsed time: 19.493915557861328 seconds.
# Random Actions Rate: 0.7590288565272548
# Sharpe ratio: 1.4883083978860532
# Cum. Ret.: 0.2569169999999983
# AVG_DRET: 0.0004605058146756831
# STD_DRET: 0.004911820149620645
# Final value: 12569.169999999984
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.49358606338500977s.  Value: 13277.38.Epoch: 5..
# Elapsed time: 19.64524221420288 seconds.
# Random Actions Rate: 0.7212149645600864
# Sharpe ratio: 1.9034230728231065
# Cum. Ret.: 0.32773799999999986
# AVG_DRET: 0.0005671556416479483
# STD_DRET: 0.00473006596555171
# Final value: 13277.38
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.36133456230163574s.  Value: 11357.150000000012.Epoch: 6
# Elapsed time: 20.784462213516235 seconds.
# Random Actions Rate: 0.6852849145752175
# Sharpe ratio: 0.8152087873264238
# Cum. Ret.: 0.13571500000000114
# AVG_DRET: 0.0002626388561476497
# STD_DRET: 0.005114349419132852
# Final value: 11357.150000000012
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.2567753791809082s.  Value: 12039.99999999999.Epoch: 7
# Elapsed time: 15.42249083518982 seconds.
# Random Actions Rate: 0.6511448558625108
# Sharpe ratio: 1.1702616168199822
# Cum. Ret.: 0.20399999999999907
# AVG_DRET: 0.0003771603485406899
# STD_DRET: 0.005116150810848689
# Final value: 12039.99999999999
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.2628340721130371s.  Value: 12652.900000000003.Epoch: 8
# Elapsed time: 11.963722467422485 seconds.
# Random Actions Rate: 0.6187056132397516
# Sharpe ratio: 1.4475867121389467
# Cum. Ret.: 0.26529000000000025
# AVG_DRET: 0.00047503707758192947
# STD_DRET: 0.005209345845512478
# Final value: 12652.900000000003
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.2209334373474121s.  Value: 12983.880000000006.Epoch: 9
# Elapsed time: 11.288394212722778 seconds.
# Random Actions Rate: 0.5878824541235491
# Sharpe ratio: 1.871188050651732
# Cum. Ret.: 0.29838800000000054
# AVG_DRET: 0.0005219192158394908
# STD_DRET: 0.004427780892774027
# Final value: 12983.880000000006
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.2044057846069336s.  Value: 12664.97.Epoch: 10..
# Elapsed time: 11.187177419662476 seconds.
# Random Actions Rate: 0.5585948672044814
# Sharpe ratio: 1.4557138572903017
# Cum. Ret.: 0.266497
# AVG_DRET: 0.0004768451355692186
# STD_DRET: 0.005199979252607082
# Final value: 12664.97
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.20816826820373535s.  Value: 13556.299999999988.Epoch: 11
# Elapsed time: 11.059983491897583 seconds.
# Random Actions Rate: 0.530766352148377
# Sharpe ratio: 1.735112823320592
# Cum. Ret.: 0.3556299999999988
# AVG_DRET: 0.0006124596590171041
# STD_DRET: 0.005603379529122213
# Final value: 13556.299999999988
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.21157407760620117s.  Value: 12884.679999999986.Epoch: 12
# Elapsed time: 11.489786863327026 seconds.
# Random Actions Rate: 0.5043242197744184
# Sharpe ratio: 1.5447981850059986
# Cum. Ret.: 0.2884679999999986
# AVG_DRET: 0.0005108400128746456
# STD_DRET: 0.005249445449609061
# Final value: 12884.679999999986
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.1758279800415039s.  Value: 11861.709999999995.Epoch: 13
# Elapsed time: 9.789609909057617 seconds.
# Random Actions Rate: 0.47919940218812873
# Sharpe ratio: 1.0557550451249735
# Cum. Ret.: 0.18617099999999964
# AVG_DRET: 0.00034854231506033104
# STD_DRET: 0.0052407400255797
# Final value: 11861.709999999995
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.22457361221313477s.  Value: 13799.049999999994.Epoch: 14
# Elapsed time: 9.274935722351074 seconds.
# Random Actions Rate: 0.45532627237330237
# Sharpe ratio: 2.0172113243585823
# Cum. Ret.: 0.37990499999999927
# AVG_DRET: 0.0006444445793806927
# STD_DRET: 0.005071476855843328
# Final value: 13799.049999999994
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.17789125442504883s.  Value: 11431.610000000015.Epoch: 15
# Elapsed time: 9.382843732833862 seconds.
# Random Actions Rate: 0.43264247277164614
# Sharpe ratio: 0.8729637959164659
# Cum. Ret.: 0.14316100000000143
# AVG_DRET: 0.00027486182790736327
# STD_DRET: 0.004998255677607302
# Final value: 11431.610000000015
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.18211126327514648s.  Value: 13333.289999999992.Epoch: 16
# Elapsed time: 9.048130989074707 seconds.
# Random Actions Rate: 0.41108875240237425
# Sharpe ratio: 1.9320153299621268
# Cum. Ret.: 0.3333289999999991
# AVG_DRET: 0.0005753921606894245
# STD_DRET: 0.004727740634077189
# Final value: 13333.289999999992
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.1792447566986084s.  Value: 13471.989999999996.Epoch: 17
# Elapsed time: 10.070430040359497 seconds.
# Random Actions Rate: 0.39060881209630455
# Sharpe ratio: 1.8769345977224756
# Cum. Ret.: 0.3471989999999996
# AVG_DRET: 0.0005972888747233251
# STD_DRET: 0.005051676788209086
# Final value: 13471.989999999996
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.18981313705444336s.  Value: 14029.300000000014.Epoch: 18
# Elapsed time: 9.41858458518982 seconds.
# Random Actions Rate: 0.3711491574402051
# Sharpe ratio: 2.4047465813217883
# Cum. Ret.: 0.40293000000000134
# AVG_DRET: 0.0006739278724830171
# STD_DRET: 0.004448815270683984
# Final value: 14029.300000000014
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.18485355377197266s.  Value: 14217.099999999995.Epoch: 19
# Elapsed time: 9.724436521530151 seconds.
# Random Actions Rate: 0.35265895904727157
# Sharpe ratio: 2.4270806454693328
# Cum. Ret.: 0.4217099999999996
# AVG_DRET: 0.0007006403316982185
# STD_DRET: 0.004582592044402788
# Final value: 14217.099999999995
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.1755847930908203s.  Value: 14913.219999999992.Epoch: 20
# Elapsed time: 8.91062307357788 seconds.
# Random Actions Rate: 0.3350899197887624
# Sharpe ratio: 2.5686594483927205
# Cum. Ret.: 0.49132199999999915
# AVG_DRET: 0.0007960350202575598
# STD_DRET: 0.004919556073852337
# Final value: 14913.219999999992
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.17713665962219238s.  Value: 14189.259999999995.Epoch: 21
# Elapsed time: 8.95983600616455 seconds.
# Random Actions Rate: 0.3183961486399896
# Sharpe ratio: 2.299041931569664
# Cum. Ret.: 0.41892599999999947
# AVG_DRET: 0.0006979070347038111
# STD_DRET: 0.0048189337307339795
# Final value: 14189.259999999995
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.18037080764770508s.  Value: 13555.230000000001.Epoch: 22
# Elapsed time: 8.91593074798584 seconds.
# Random Actions Rate: 0.30253404081115
# Sharpe ratio: 1.9564238614961518
# Cum. Ret.: 0.35552300000000003
# AVG_DRET: 0.0006088064297249875
# STD_DRET: 0.004939881713764121
# Final value: 13555.230000000001
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.17838263511657715s.  Value: 12458.760000000007.Epoch: 23
# Elapsed time: 8.83991003036499 seconds.
# Random Actions Rate: 0.2874621638498909
# Sharpe ratio: 1.3639884419441635
# Cum. Ret.: 0.24587600000000065
# AVG_DRET: 0.00044451670089975306
# STD_DRET: 0.005173419105455026
# Final value: 12458.760000000007
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.1770780086517334s.  Value: 12378.300000000012.Epoch: 24
# Elapsed time: 8.845827341079712 seconds.
# Random Actions Rate: 0.27314114941810486
# Sharpe ratio: 1.5177597313011293
# Cum. Ret.: 0.2378300000000011
# AVG_DRET: 0.0004284771019616682
# STD_DRET: 0.004481515081327404
# Final value: 12378.300000000012
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.17905926704406738s.  Value: 13882.419999999996.Epoch: 25
# Elapsed time: 8.917689085006714 seconds.
# Random Actions Rate: 0.25953359046027974
# Sharpe ratio: 2.1663410392911944
# Cum. Ret.: 0.38824199999999975
# AVG_DRET: 0.0006549014995758277
# STD_DRET: 0.004798985394343553
# Final value: 13882.419999999996
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.1742563247680664s.  Value: 15300.790000000012.Epoch: 26
# Elapsed time: 8.841050624847412 seconds.
# Random Actions Rate: 0.24660394349478965
# Sharpe ratio: 2.887324820660503
# Cum. Ret.: 0.5300790000000011
# AVG_DRET: 0.0008450567767543054
# STD_DRET: 0.004646120988584009
# Final value: 15300.790000000012
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.17792463302612305s.  Value: 14077.440000000004.Epoch: 27
# Elapsed time: 8.852691173553467 seconds.
# Random Actions Rate: 0.23431843577291622
# Sharpe ratio: 2.382114148885752
# Cum. Ret.: 0.40774400000000033
# AVG_DRET: 0.000681057215484093
# STD_DRET: 0.004538593639485896
# Final value: 14077.440000000004
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.1765425205230713s.  Value: 13407.73000000001.Epoch: 28
# Elapsed time: 8.889798879623413 seconds.
# Random Actions Rate: 0.22264497706309516
# Sharpe ratio: 2.34095000301618
# Cum. Ret.: 0.3407730000000011
# AVG_DRET: 0.0005829428417709105
# STD_DRET: 0.003953066368535624
# Final value: 13407.73000000001
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.1803443431854248s.  Value: 13988.950000000004.Epoch: 29
# Elapsed time: 8.87976622581482 seconds.
# Random Actions Rate: 0.21155307582996363
# Sharpe ratio: 2.492229884539443
# Cum. Ret.: 0.39889500000000044
# AVG_DRET: 0.0006674346704958422
# STD_DRET: 0.004251291982659131
# Final value: 13988.950000000004
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.20467925071716309s.  Value: 14485.51000000001..Epoch: 30
# Elapsed time: 9.145650863647461 seconds.
# Random Actions Rate: 0.20101375958926435
# Sharpe ratio: 2.5548115443233597
# Cum. Ret.: 0.44855100000000103
# AVG_DRET: 0.0007373129664494111
# STD_DRET: 0.004581347893114612
# Final value: 14485.51000000001
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.20503807067871094s.  Value: 13826.07000000001..Epoch: 31
# Elapsed time: 10.725353717803955 seconds.
# Random Actions Rate: 0.19099949923057333
# Sharpe ratio: 2.2909774941914964
# Cum. Ret.: 0.38260700000000103
# AVG_DRET: 0.0006454123541736515
# STD_DRET: 0.004472153707039835
# Final value: 13826.07000000001
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.1974029541015625s.  Value: 12717.700000000008.Epoch: 32
# Elapsed time: 9.702061653137207 seconds.
# Random Actions Rate: 0.181484137110175
# Sharpe ratio: 1.860405246422101
# Cum. Ret.: 0.27177000000000073
# AVG_DRET: 0.00047987616487290007
# STD_DRET: 0.004094698167948706
# Final value: 12717.700000000008
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.18157720565795898s.  Value: 13022.159999999993.Epoch: 33
# Elapsed time: 9.26775598526001 seconds.
# Random Actions Rate: 0.17244281872626321
# Sharpe ratio: 1.9741958025909911
# Cum. Ret.: 0.30221599999999915
# AVG_DRET: 0.0005268667537092846
# STD_DRET: 0.004236535411188334
# Final value: 13022.159999999993
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.17238306999206543s.  Value: 13939.57999999999.Epoch: 34
# Elapsed time: 9.307846546173096 seconds.
# Random Actions Rate: 0.16385192779800092
# Sharpe ratio: 2.5993164946192677
# Cum. Ret.: 0.39395799999999914
# AVG_DRET: 0.0006595687917389441
# STD_DRET: 0.004028108925772514
# Final value: 13939.57999999999
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.1827089786529541s.  Value: 14554.070000000002.Epoch: 35
# Elapsed time: 9.057823419570923 seconds.
# Random Actions Rate: 0.15568902457886089
# Sharpe ratio: 3.1198357816973292
# Cum. Ret.: 0.4554070000000001
# AVG_DRET: 0.0007432558085624804
# STD_DRET: 0.003781872189870278
# Final value: 14554.070000000002
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.18596911430358887s.  Value: 13540.68000000002.Epoch: 36
# Elapsed time: 9.118211507797241 seconds.
# Random Actions Rate: 0.14793278724312292
# Sharpe ratio: 2.2290416791572953
# Cum. Ret.: 0.35406800000000205
# AVG_DRET: 0.0006037439119094892
# STD_DRET: 0.00429966723749828
# Final value: 13540.68000000002
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.18506383895874023s.  Value: 13829.909999999994.Epoch: 37
# Elapsed time: 9.942773580551147 seconds.
# Random Actions Rate: 0.1405629561924203
# Sharpe ratio: 2.293927106628935
# Cum. Ret.: 0.3829909999999994
# AVG_DRET: 0.0006459487640415803
# STD_DRET: 0.0044701153347154205
# Final value: 13829.909999999994
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.173431396484375s.  Value: 14541.009999999982.Epoch: 38
# Elapsed time: 9.732189416885376 seconds.
# Random Actions Rate: 0.13356028113686985
# Sharpe ratio: 2.8186746407213668
# Cum. Ret.: 0.4541009999999983
# AVG_DRET: 0.0007430995662185474
# STD_DRET: 0.004185066179339711
# Final value: 14541.009999999982
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.17499828338623047s.  Value: 13834.509999999995.Epoch: 39
# Elapsed time: 9.499476909637451 seconds.
# Random Actions Rate: 0.12690647081255405
# Sharpe ratio: 2.4010527558731756
# Cum. Ret.: 0.38345099999999954
# AVG_DRET: 0.0006457369437132801
# STD_DRET: 0.0042692757031345145
# Final value: 13834.509999999995
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.1831834316253662s.  Value: 15320.180000000006.Epoch: 40
# Elapsed time: 9.97050929069519 seconds.
# Random Actions Rate: 0.12058414520401681
# Sharpe ratio: 3.2738802859158618
# Cum. Ret.: 0.5320180000000005
# AVG_DRET: 0.000845161638204842
# STD_DRET: 0.004098049990333872
# Final value: 15320.180000000006
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.18218207359313965s.  Value: 16424.319999999992.Epoch: 41
# Elapsed time: 9.785254716873169 seconds.
# Random Actions Rate: 0.1145767901469767
# Sharpe ratio: 3.6240139243787195
# Cum. Ret.: 0.6424319999999992
# AVG_DRET: 0.0009825971394644964
# STD_DRET: 0.004304135233860373
# Final value: 16424.319999999992
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.17033934593200684s.  Value: 15573.999999999995.Epoch: 42
# Elapsed time: 9.20365309715271 seconds.
# Random Actions Rate: 0.1088687141926769
# Sharpe ratio: 3.2711830947345044
# Cum. Ret.: 0.5573999999999995
# AVG_DRET: 0.0008780831231757311
# STD_DRET: 0.004261191453524131
# Final value: 15573.999999999995
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.18132257461547852s.  Value: 16427.810000000012.Epoch: 43
# Elapsed time: 9.499610424041748 seconds.
# Random Actions Rate: 0.10344500762120107
# Sharpe ratio: 3.7671794961333678
# Cum. Ret.: 0.6427810000000012
# AVG_DRET: 0.0009823173178663885
# STD_DRET: 0.00413938438711619
# Final value: 16427.810000000012
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.1816565990447998s.  Value: 16097.770000000004.Epoch: 44
# Elapsed time: 9.446462869644165 seconds.
# Random Actions Rate: 0.09829150349669633
# Sharpe ratio: 3.6113466250770343
# Cum. Ret.: 0.6097770000000005
# AVG_DRET: 0.0009425009124230211
# STD_DRET: 0.004142980362074088
# Final value: 16097.770000000004
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.17146921157836914s.  Value: 16711.639999999996.Epoch: 45
# Elapsed time: 9.542055368423462 seconds.
# Random Actions Rate: 0.0933947406627772
# Sharpe ratio: 3.5475547257727373
# Cum. Ret.: 0.6711639999999996
# AVG_DRET: 0.001017737384796278
# STD_DRET: 0.004554145424027545
# Final value: 16711.639999999996
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.18221712112426758s.  Value: 16253.790000000012.Epoch: 46
# Elapsed time: 9.53568172454834 seconds.
# Random Actions Rate: 0.08874192858145223
# Sharpe ratio: 3.3571265225809688
# Cum. Ret.: 0.6253790000000012
# AVG_DRET: 0.0009632111588850008
# STD_DRET: 0.004554640111376209
# Final value: 16253.790000000012
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.18295693397521973s.  Value: 15415.830000000002.Epoch: 47
# Elapsed time: 8.95559048652649 seconds.
# Random Actions Rate: 0.0843209139237348
# Sharpe ratio: 3.027325382516106
# Cum. Ret.: 0.5415830000000001
# AVG_DRET: 0.0008591065492744408
# STD_DRET: 0.00450493156542931
# Final value: 15415.830000000002
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.20671343803405762s.  Value: 15688.900000000001.Epoch: 48
# Elapsed time: 8.86322808265686 seconds.
# Random Actions Rate: 0.08012014882466674
# Sharpe ratio: 3.3404141880090656
# Cum. Ret.: 0.5688900000000001
# AVG_DRET: 0.0008924153964062253
# STD_DRET: 0.004240987623986686
# Final value: 15688.900000000001
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.1735823154449463s.  Value: 15202.580000000002.Epoch: 49
# Elapsed time: 9.19058632850647 seconds.
# Random Actions Rate: 0.07612866071983868
# Sharpe ratio: 3.0188969724206025
# Cum. Ret.: 0.5202580000000001
# AVG_DRET: 0.0008312004876358721
# STD_DRET: 0.0043707681315606215
# Final value: 15202.580000000002
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.17569732666015625s.  Value: 14755.689999999995.Epoch: 50
# Elapsed time: 9.016286849975586 seconds.
# Random Actions Rate: 0.07233602368461936
# Sharpe ratio: 3.0865444976243985
# Cum. Ret.: 0.47556899999999946
# AVG_DRET: 0.0007709558662827758
# STD_DRET: 0.003965128308813663
# Final value: 14755.689999999995
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.1759321689605713s.  Value: 15671.88999999999.Epoch: 51
# Elapsed time: 9.343532085418701 seconds.
# Random Actions Rate: 0.06873233120122733
# Sharpe ratio: 3.6389937725091155
# Cum. Ret.: 0.567188999999999
# AVG_DRET: 0.0008888165667281571
# STD_DRET: 0.0038773151212548153
# Final value: 15671.88999999999
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.1885221004486084s.  Value: 15745.640000000003.Epoch: 52
# Elapsed time: 9.054616689682007 seconds.
# Random Actions Rate: 0.06530817028251568
# Sharpe ratio: 3.369745589945976
# Cum. Ret.: 0.5745640000000003
# AVG_DRET: 0.0008995047533322552
# STD_DRET: 0.004237469833102385
# Final value: 15745.640000000003
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.1778109073638916s.  Value: 15428.919999999993.Epoch: 53
# Elapsed time: 9.23362112045288 seconds.
# Random Actions Rate: 0.06205459688487778
# Sharpe ratio: 3.498036570534288
# Cum. Ret.: 0.5428919999999993
# AVG_DRET: 0.0008582245387986924
# STD_DRET: 0.0038947254888778244
# Final value: 15428.919999999993
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.18592095375061035s.  Value: 14958.89000000001.Epoch: 54
# Elapsed time: 9.152198314666748 seconds.
# Random Actions Rate: 0.058963112546051695
# Sharpe ratio: 3.0188562591634884
# Cum. Ret.: 0.49588900000000113
# AVG_DRET: 0.0007987569046781649
# STD_DRET: 0.004200224084255814
# Final value: 14958.89000000001
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.1868298053741455s.  Value: 15518.37000000001.Epoch: 55
# Elapsed time: 9.013103723526001 seconds.
# Random Actions Rate: 0.0560256421868013
# Sharpe ratio: 3.7132080032451276
# Cum. Ret.: 0.551837000000001
# AVG_DRET: 0.0008688825118390102
# STD_DRET: 0.0037145999516053465
# Final value: 15518.37000000001
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.18927001953125s.  Value: 16245.23000000002.Epoch: 56
# Elapsed time: 9.028316020965576 seconds.
# Random Actions Rate: 0.0532345130184901
# Sharpe ratio: 4.270733919699092
# Cum. Ret.: 0.6245230000000019
# AVG_DRET: 0.0009581581661886099
# STD_DRET: 0.003561516505686742
# Final value: 16245.23000000002
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.18101978302001953s.  Value: 15299.94.Epoch: 57.
# Elapsed time: 9.19041657447815 seconds.
# Random Actions Rate: 0.05058243450145431
# Sharpe ratio: 3.332205071158866
# Cum. Ret.: 0.5299940000000001
# AVG_DRET: 0.0008422236148407383
# STD_DRET: 0.004012323705634632
# Final value: 15299.94
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.19022321701049805s.  Value: 15844.18.Epoch: 58.
# Elapsed time: 9.278326034545898 seconds.
# Random Actions Rate: 0.048062479301825056
# Sharpe ratio: 3.451886050803208
# Cum. Ret.: 0.5844180000000001
# AVG_DRET: 0.0009115484218217025
# STD_DRET: 0.004192022094540086
# Final value: 15844.18
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.17839598655700684s.  Value: 15187.810000000014.Epoch: 59
# Elapsed time: 9.10963773727417 seconds.
# Random Actions Rate: 0.04566806519705862
# Sharpe ratio: 3.2262300142361875
# Cum. Ret.: 0.5187810000000015
# AVG_DRET: 0.0008280316236130506
# STD_DRET: 0.0040742893298558
# Final value: 15187.810000000014
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.18405413627624512s.  Value: 15445.440000000011.Epoch: 60
# Elapsed time: 9.09959864616394 seconds.
# Random Actions Rate: 0.04339293788291116
# Sharpe ratio: 3.6979513576986447
# Cum. Ret.: 0.5445440000000012
# AVG_DRET: 0.0008595396180292267
# STD_DRET: 0.003689818255578215
# Final value: 15445.440000000011
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.18468141555786133s.  Value: 16366.850000000006.Epoch: 61
# Elapsed time: 8.973915576934814 seconds.
# Random Actions Rate: 0.041231154636948875
# Sharpe ratio: 4.334829026846586
# Cum. Ret.: 0.6366850000000006
# AVG_DRET: 0.0009727972171563817
# STD_DRET: 0.003562465089282384
# Final value: 16366.850000000006
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.17379331588745117s.  Value: 16375.589999999998.Epoch: 62
# Elapsed time: 8.940819501876831 seconds.
# Random Actions Rate: 0.039177068795922226
# Sharpe ratio: 4.315758763820502
# Cum. Ret.: 0.6375589999999998
# AVG_DRET: 0.0009739178547805565
# STD_DRET: 0.0035823287382362712
# Final value: 16375.589999999998
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.2535271644592285s.  Value: 16752.639999999996.Epoch: 63
# Elapsed time: 9.175649642944336 seconds.
# Random Actions Rate: 0.03722531500645846
# Sharpe ratio: 4.367900734890499
# Cum. Ret.: 0.6752639999999996
# AVG_DRET: 0.0010190375350028784
# STD_DRET: 0.0037035455582423867
# Final value: 16752.639999999996
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.18213868141174316s.  Value: 15624.900000000012.Epoch: 64
# Elapsed time: 9.516453981399536 seconds.
# Random Actions Rate: 0.03537079521054669
# Sharpe ratio: 3.756640534247835
# Cum. Ret.: 0.5624900000000013
# AVG_DRET: 0.000882354679378085
# STD_DRET: 0.003728583070707823
# Final value: 15624.900000000012
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.21978116035461426s.  Value: 16528.710000000003.Epoch: 65
# Elapsed time: 10.120463132858276 seconds.
# Random Actions Rate: 0.03360866532920866
# Sharpe ratio: 4.3992683210583134
# Cum. Ret.: 0.6528710000000002
# AVG_DRET: 0.000992174522997019
# STD_DRET: 0.0035802049615278994
# Final value: 16528.710000000003
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.1840801239013672s.  Value: 15468.360000000008.Epoch: 66
# Elapsed time: 9.297157526016235 seconds.
# Random Actions Rate: 0.03193432260957338
# Sharpe ratio: 3.44339781811254
# Cum. Ret.: 0.5468360000000008
# AVG_DRET: 0.0008635839148900935
# STD_DRET: 0.003981233181393766
# Final value: 15468.360000000008
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.18333911895751953s.  Value: 16608.419999999987.Epoch: 67
# Elapsed time: 9.374356746673584 seconds.
# Random Actions Rate: 0.030343393602304713
# Sharpe ratio: 4.393282192708044
# Cum. Ret.: 0.6608419999999988
# AVG_DRET: 0.0010017599511134658
# STD_DRET: 0.003619718817647895
# Final value: 16608.419999999987
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.17294692993164062s.  Value: 16026.200000000006.Epoch: 68
# Elapsed time: 8.907432317733765 seconds.
# Random Actions Rate: 0.02883172273797876
# Sharpe ratio: 3.9536412841488278
# Cum. Ret.: 0.6026200000000006
# AVG_DRET: 0.0009321754089485623
# STD_DRET: 0.003742834718348196
# Final value: 16026.200000000006
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.24232172966003418s.  Value: 15519.840000000004.Epoch: 69
# Elapsed time: 9.713138818740845 seconds.
# Random Actions Rate: 0.027395361472572485
# Sharpe ratio: 3.729540385693707
# Cum. Ret.: 0.5519840000000005
# AVG_DRET: 0.0008690087479714847
# STD_DRET: 0.0036988703108163266
# Final value: 15519.840000000004
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.17053556442260742s.  Value: 15872.529999999992.Epoch: 70
# Elapsed time: 9.565125465393066 seconds.
# Random Actions Rate: 0.026030557973710747
# Sharpe ratio: 4.149380003957574
# Cum. Ret.: 0.5872529999999991
# AVG_DRET: 0.0009123549654771902
# STD_DRET: 0.003490445816626025
# Final value: 15872.529999999992
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.2140488624572754s.  Value: 16156.600000000006.Epoch: 71
# Elapsed time: 9.19975471496582 seconds.
# Random Actions Rate: 0.024733747320731667
# Sharpe ratio: 4.099327150031301
# Cum. Ret.: 0.6156600000000005
# AVG_DRET: 0.0009478132054743601
# STD_DRET: 0.0036703750726637756
# Final value: 16156.600000000006
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.16861343383789062s.  Value: 16334.320000000005.Epoch: 72
# Elapsed time: 9.018269300460815 seconds.
# Random Actions Rate: 0.023501542192973277
# Sharpe ratio: 4.269663623456597
# Cum. Ret.: 0.6334320000000004
# AVG_DRET: 0.0009690360145436301
# STD_DRET: 0.0036028528690585887
# Final value: 16334.320000000005
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.16838431358337402s.  Value: 15324.839999999991.Epoch: 73
# Elapsed time: 8.889803647994995 seconds.
# Random Actions Rate: 0.022330724021958074
# Sharpe ratio: 3.51796672796872
# Cum. Ret.: 0.5324839999999991
# AVG_DRET: 0.0008446166247230746
# STD_DRET: 0.0038112564131582544
# Final value: 15324.839999999991
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.17415213584899902s.  Value: 16101.44000000001.Epoch: 74
# Elapsed time: 9.131618738174438 seconds.
# Random Actions Rate: 0.021218234584364847
# Sharpe ratio: 4.2454791552537765
# Cum. Ret.: 0.6101440000000009
# AVG_DRET: 0.0009405481857987331
# STD_DRET: 0.0035168561729249682
# Final value: 16101.44000000001
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.17751431465148926s.  Value: 16744.980000000003.Epoch: 75
# Elapsed time: 8.898557901382446 seconds.
# Random Actions Rate: 0.020161168013828664
# Sharpe ratio: 4.564030387710575
# Cum. Ret.: 0.6744980000000003
# AVG_DRET: 0.001017542808250088
# STD_DRET: 0.003539194514884642
# Final value: 16744.980000000003
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.16883587837219238s.  Value: 16045.240000000002.Epoch: 76
# Elapsed time: 9.137015342712402 seconds.
# Random Actions Rate: 0.01915676321070301
# Sharpe ratio: 4.095350184159095
# Cum. Ret.: 0.6045240000000001
# AVG_DRET: 0.0009340578207084098
# STD_DRET: 0.0036206203513072855
# Final value: 16045.240000000002
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.16866803169250488s.  Value: 16241.360000000006.Epoch: 77
# Elapsed time: 8.49469256401062 seconds.
# Random Actions Rate: 0.01820239662995867
# Sharpe ratio: 4.247094759102664
# Cum. Ret.: 0.6241360000000007
# AVG_DRET: 0.0009577544857820577
# STD_DRET: 0.0035798309152460595
# Final value: 16241.360000000006
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.17293453216552734s.  Value: 15830.950000000004.Epoch: 78
# Elapsed time: 8.606167078018188 seconds.
# Random Actions Rate: 0.017295575428380113
# Sharpe ratio: 3.883193153525314
# Cum. Ret.: 0.5830950000000004
# AVG_DRET: 0.0009080092753437365
# STD_DRET: 0.0037119452508076315
# Final value: 15830.950000000004
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.16936135292053223s.  Value: 16103.980000000005.Epoch: 79
# Elapsed time: 8.528602600097656 seconds.
# Random Actions Rate: 0.016433930953160716
# Sharpe ratio: 4.253031909547043
# Cum. Ret.: 0.6103980000000004
# AVG_DRET: 0.0009408397224811852
# STD_DRET: 0.0035116989228345806
# Final value: 16103.980000000005
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.16931986808776855s.  Value: 15888.230000000012.Epoch: 80
# Elapsed time: 8.53423261642456 seconds.
# Random Actions Rate: 0.015615212554888005
# Sharpe ratio: 3.9111142430060135
# Cum. Ret.: 0.5888230000000012
# AVG_DRET: 0.000915105141568081
# STD_DRET: 0.0037142468528940523
# Final value: 15888.230000000012
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.20903587341308594s.  Value: 15818.12.Epoch: 81.
# Elapsed time: 9.500950574874878 seconds.
# Random Actions Rate: 0.014837281708758508
# Sharpe ratio: 3.831276196016076
# Cum. Ret.: 0.581812
# AVG_DRET: 0.0009065863098907589
# STD_DRET: 0.0037563492610856713
# Final value: 15818.12
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.16986346244812012s.  Value: 15584.140000000007.Epoch: 82
# Elapsed time: 8.440160512924194 seconds.
# Random Actions Rate: 0.014098106428666457
# Sharpe ratio: 3.781102512459601
# Cum. Ret.: 0.5584140000000006
# AVG_DRET: 0.0008770619865792378
# STD_DRET: 0.0036822401295342707
# Final value: 15584.140000000007
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.17044448852539062s.  Value: 16497.720000000012.Epoch: 83
# Elapsed time: 8.459048986434937 seconds.
# Random Actions Rate: 0.013395755959575806
# Sharpe ratio: 4.413390279801266
# Cum. Ret.: 0.6497720000000011
# AVG_DRET: 0.0009884025185389674
# STD_DRET: 0.0035551815182795557
# Final value: 16497.720000000012
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.1713244915008545s.  Value: 16117.420000000002.Epoch: 84
# Elapsed time: 8.58083724975586 seconds.
# Random Actions Rate: 0.012728395734311705
# Sharpe ratio: 4.2481497071785
# Cum. Ret.: 0.6117420000000002
# AVG_DRET: 0.0009425136303136011
# STD_DRET: 0.0035219898237833134
# Final value: 16117.420000000002
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.16928315162658691s.  Value: 15835.76.Epoch: 85.
# Elapsed time: 9.176735877990723 seconds.
# Random Actions Rate: 0.01209428258159868
# Sharpe ratio: 4.005731414143301
# Cum. Ret.: 0.5835760000000001
# AVG_DRET: 0.0009081882322871211
# STD_DRET: 0.0035991033214806414
# Final value: 15835.76
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.1751720905303955s.  Value: 16401.610000000008.Epoch: 86
# Elapsed time: 10.326940774917603 seconds.
# Random Actions Rate: 0.011491760172828321
# Sharpe ratio: 4.3581929375024515
# Cum. Ret.: 0.6401610000000009
# AVG_DRET: 0.000976947586539283
# STD_DRET: 0.0035584845301625543
# Final value: 16401.610000000008
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.1709461212158203s.  Value: 16537.67000000001.Epoch: 87
# Elapsed time: 8.850577354431152 seconds.
# Random Actions Rate: 0.010919254695663535
# Sharpe ratio: 4.462895284839691
# Cum. Ret.: 0.6537670000000009
# AVG_DRET: 0.0009930680820265073
# STD_DRET: 0.003532340795344125
# Final value: 16537.67000000001
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.1728062629699707s.  Value: 16241.2.Epoch: 8801.
# Elapsed time: 9.581294059753418 seconds.
# Random Actions Rate: 0.010375270743178537
# Sharpe ratio: 4.2293830301831274
# Cum. Ret.: 0.62412
# AVG_DRET: 0.0009577886817800583
# STD_DRET: 0.003594950813096765
# Final value: 16241.2
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.17541241645812988s.  Value: 16190.160000000003.Epoch: 89
# Elapsed time: 9.0694100856781 seconds.
# Random Actions Rate: 0.009858387407796935
# Sharpe ratio: 4.093261270288565
# Cum. Ret.: 0.6190160000000005
# AVG_DRET: 0.000951961660509159
# STD_DRET: 0.0036919028301329614
# Final value: 16190.160000000003
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.1782214641571045s.  Value: 16848.81000000001.Epoch: 90
# Elapsed time: 9.562458992004395 seconds.
# Random Actions Rate: 0.009367254569824821
# Sharpe ratio: 4.145747763304987
# Cum. Ret.: 0.684881000000001
# AVG_DRET: 0.0010312071959285491
# STD_DRET: 0.0039486017187387
# Final value: 16848.81000000001
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.18301081657409668s.  Value: 16728.78000000001.Epoch: 91
# Elapsed time: 9.069365501403809 seconds.
# Random Actions Rate: 0.00890058937088502
# Sharpe ratio: 4.086309991039972
# Cum. Ret.: 0.672878000000001
# AVG_DRET: 0.0010171859727314584
# STD_DRET: 0.00395156675854518
# Final value: 16728.78000000001
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.1855320930480957s.  Value: 16473.020000000008.Epoch: 92
# Elapsed time: 8.805707454681396 seconds.
# Random Actions Rate: 0.008457172863040143
# Sharpe ratio: 3.9139160518855864
# Cum. Ret.: 0.6473020000000007
# AVG_DRET: 0.0009871567927689211
# STD_DRET: 0.004003823297287785
# Final value: 16473.020000000008
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.17278337478637695s.  Value: 16737.27.Epoch: 93.
# Elapsed time: 9.135034322738647 seconds.
# Random Actions Rate: 0.008035846824852543
# Sharpe ratio: 4.130798536982152
# Cum. Ret.: 0.673727
# AVG_DRET: 0.0010180273449050565
# STD_DRET: 0.003912241894686904
# Final value: 16737.27
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.23800396919250488s.  Value: 17066.480000000003.Epoch: 94
# Elapsed time: 10.542988300323486 seconds.
# Random Actions Rate: 0.007635510736064084
# Sharpe ratio: 3.931601516796464
# Cum. Ret.: 0.7066480000000004
# AVG_DRET: 0.0010577244900179777
# STD_DRET: 0.00427074200310682
# Final value: 17066.480000000003
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.1792738437652588s.  Value: 16751.83.Epoch: 957.
# Elapsed time: 9.94458532333374 seconds.
# Random Actions Rate: 0.007255118902993726
# Sharpe ratio: 4.090985916356208
# Cum. Ret.: 0.6751830000000001
# AVG_DRET: 0.0010199125089433052
# STD_DRET: 0.003957630135443815
# Final value: 16751.83
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.17046880722045898s.  Value: 16810.120000000006.Epoch: 96
# Elapsed time: 8.823260307312012 seconds.
# Random Actions Rate: 0.006893677727144397
# Sharpe ratio: 4.1442800533535245
# Cum. Ret.: 0.6810120000000006
# AVG_DRET: 0.0010266310397167406
# STD_DRET: 0.003932471335443024
# Final value: 16810.120000000006
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.1789562702178955s.  Value: 16857.180000000004.Epoch: 97
# Elapsed time: 8.920802354812622 seconds.
# Random Actions Rate: 0.0065502431098844035
# Sharpe ratio: 4.156682996413681
# Cum. Ret.: 0.6857180000000005
# AVG_DRET: 0.0010321552782557289
# STD_DRET: 0.003941834654733274
# Final value: 16857.180000000004
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.1773514747619629s.  Value: 16682.780000000006.Epoch: 98
# Elapsed time: 9.188677787780762 seconds.
# Random Actions Rate: 0.0062239179864245105
# Sharpe ratio: 4.1013433580662975
# Cum. Ret.: 0.6682780000000006
# AVG_DRET: 0.0010116400487053517
# STD_DRET: 0.003915616545379273
# Final value: 16682.780000000006
# ----------------------------------------------------------------------------------------------------
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.18070650100708008s.  Value: 16781.260000000002.Epoch: 99
# Elapsed time: 9.004882335662842 seconds.
# Random Actions Rate: 0.005913849982649292
# Sharpe ratio: 4.138352599008413
# Cum. Ret.: 0.6781260000000002
# AVG_DRET: 0.0010232290586990505
# STD_DRET: 0.0039250540771529315
# Final value: 16781.260000000002
# ----------------------------------------------------------------------------------------------------

# %%
env.reset(STARTING_DAYS_AHEAD)
results_list = sim.simulate_period(total_data_in_df, 
                                   SYMBOL, 
                                   agents[0], 
                                   learn=False, 
                                   starting_days_ahead=STARTING_DAYS_AHEAD,
                                   possible_fractions=POSSIBLE_FRACTIONS,
                                   other_env=env)
show_results([results_list], data_in_df, graph=True)
# Out:
# Starting simulation for agent: Agent_0. 512 days of simulation to go.
# Date 2014-12-31 00:00:00 (simulating until 2014-12-31 00:00:00).  Time: 0.1710643768310547s.  Value: 16627.28000000001.Sharpe ratio: 4.093353629096188
# Cum. Ret.: 0.6627280000000009
# AVG_DRET: 0.001005030237404575
# STD_DRET: 0.00389762572581812
# Final value: 16627.28000000001
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Let's run the trained agent, with the test set

# %% [markdown]
# ### First a non-learning test: this scenario would be worse than what is possible (in fact, the q-learner can learn from past samples in the test set without compromising the causality).

# %%
TEST_DAYS_AHEAD = 20

env.set_test_data(total_data_test_df, TEST_DAYS_AHEAD)
tic = time()
results_list = sim.simulate_period(total_data_test_df, 
                                    SYMBOL,
                                    agents[0],
                                    learn=False,
                                    starting_days_ahead=TEST_DAYS_AHEAD,
                                    possible_fractions=POSSIBLE_FRACTIONS,
                                    verbose=False,
                                    other_env=env)
toc = time()
print('Epoch: {}'.format(i))
print('Elapsed time: {} seconds.'.format((toc-tic)))
print('Random Actions Rate: {}'.format(agents[0].random_actions_rate))
show_results([results_list], data_test_df, graph=True)
# Out:
# Starting simulation for agent: Agent_0. 484 days of simulation to go.
# Date 2016-12-28 00:00:00 (simulating until 2016-12-30 00:00:00).  Time: 0.20259761810302734s.  Value: 11003.239999999998.Epoch: 99
# Elapsed time: 9.116246461868286 seconds.
# Random Actions Rate: 0.005913849982649292
# Sharpe ratio: 0.6420028402682839
# Cum. Ret.: 0.10032399999999986
# AVG_DRET: 0.00021212869921389494
# STD_DRET: 0.005245208421430546
# Final value: 11003.239999999998
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ### And now a "realistic" test, in which the learner continues to learn from past samples in the test set (it even makes some random moves, though very few).

# %%
env.set_test_data(total_data_test_df, TEST_DAYS_AHEAD)
tic = time()
results_list = sim.simulate_period(total_data_test_df, 
                                    SYMBOL,
                                    agents[0],
                                    learn=True,
                                    starting_days_ahead=TEST_DAYS_AHEAD,
                                    possible_fractions=POSSIBLE_FRACTIONS,
                                    verbose=False,
                                    other_env=env)
toc = time()
print('Epoch: {}'.format(i))
print('Elapsed time: {} seconds.'.format((toc-tic)))
print('Random Actions Rate: {}'.format(agents[0].random_actions_rate))
show_results([results_list], data_test_df, graph=True)
# Out:
# Starting simulation for agent: Agent_0. 484 days of simulation to go.
# Date 2016-12-28 00:00:00 (simulating until 2016-12-30 00:00:00).  Time: 0.1994168758392334s.  Value: 10080.580000000005..Epoch: 99
# Elapsed time: 8.653764009475708 seconds.
# Random Actions Rate: 0.005634985867312839
# Sharpe ratio: 0.09274627213069256
# Cum. Ret.: 0.008058000000000565
# AVG_DRET: 2.89409714531101e-05
# STD_DRET: 0.004953554126099009
# Final value: 10080.580000000005
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ## What are the metrics for "holding the position"?

# %%
print('Sharpe ratio: {}\nCum. Ret.: {}\nAVG_DRET: {}\nSTD_DRET: {}\nFinal value: {}'.format(*value_eval(pd.DataFrame(data_test_df['Close'].iloc[TEST_DAYS_AHEAD:]))))
# Out:
# Sharpe ratio: 0.44271542660031676
# Cum. Ret.: 0.1070225832012679
# AVG_DRET: 0.00025103195406808796
# STD_DRET: 0.009001287260690292
# Final value: 223.53

# %%
import pickle
with open('../../data/simple_q_learner.pkl', 'wb') as best_agent:
    pickle.dump(agents[0], best_agent)
